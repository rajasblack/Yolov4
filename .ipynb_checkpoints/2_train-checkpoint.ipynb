# %% [markdown]
# <h2>Training the Model

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"


from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
import shutil
import numpy as np
import tensorflow as tf
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config=ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

from input_log_utils_others.yolov3.dataset import Dataset
from input_log_utils_others.yolov3.yolov4 import Create_Yolo, compute_loss
from input_log_utils_others.yolov3.utils import load_yolo_weights
from input_log_utils_others.yolov3.configs import *
from input_log_utils_others.evaluate_mAP import get_mAP

if YOLO_TYPE == "yolov4":
    Darknet_weights = YOLO_V4_TINY_WEIGHTS if TRAIN_YOLO_TINY else YOLO_V4_WEIGHTS
if YOLO_TYPE == "yolov3":
    Darknet_weights = YOLO_V3_TINY_WEIGHTS if TRAIN_YOLO_TINY else YOLO_V3_WEIGHTS
    
if TRAIN_YOLO_TINY: TRAIN_MODEL_NAME += "_Tiny"
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1449011547201874508
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14523623013445680984
# physical_device_desc: "device: XLA_CPU device"
# ]

# %%
global TRAIN_FROM_CHECKPOINT

gpus = tf.config.experimental.list_physical_devices('GPU')
print(f'GPUs {gpus}')
if len(gpus)>0:
    try: tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError: pass

if os.path.exists(TRAIN_LOGDIR): shutil.rmtree(TRAIN_LOGDIR)
writer = tf.summary.create_file_writer(TRAIN_LOGDIR)
# Out:
# GPUs []

# %%
trainset = Dataset('train')
testset = Dataset('test')
steps_per_epoch = len(trainset)
global_steps = tf.Variable(1, trainable=False, dtype=tf.int64)
warmup_steps = TRAIN_WARMUP_EPOCHS * steps_per_epoch
total_steps = TRAIN_EPOCHS * steps_per_epoch


if TRAIN_TRANSFER:
    Darknet = Create_Yolo(input_size=YOLO_INPUT_SIZE, CLASSES=YOLO_COCO_CLASSES)
    load_yolo_weights(Darknet, Darknet_weights)
    
yolo = Create_Yolo(input_size=YOLO_INPUT_SIZE, training=True, CLASSES=TRAIN_CLASSES)
# Out:
# annotations #:  25
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 trainset = Dataset('train')
#       2 testset = Dataset('test')
#       3 steps_per_epoch = len(trainset)
#
# File ~\MyDocuments\Digital Lighthouse\trash_detection\input_log_utils_others\yolov3\dataset.py:38, in Dataset.__init__(self, dataset_type, TEST_INPUT_SIZE)
#      35 self.anchor_per_scale = YOLO_ANCHOR_PER_SCALE
#      36 self.max_bbox_per_scale = YOLO_MAX_BBOX_PER_SCALE
# ---> 38 self.annotations = self.load_annotations(dataset_type)
#      39 self.num_samples = len(self.annotations)
#      40 self.num_batchs = int(np.ceil(self.num_samples / self.batch_size))
#
# File ~\MyDocuments\Digital Lighthouse\trash_detection\input_log_utils_others\yolov3\dataset.py:66, in Dataset.load_annotations(self, dataset_type)
#      64 image_path = image_path.split(" ")[0]
#      65 if not os.path.exists(image_path):
# ---> 66     raise KeyError("%s does not exist ... " %image_path)
#      67 if TRAIN_LOAD_IMAGES_TO_RAM:
#      68     image = cv2.imread(image_path)
#
# KeyError: '.\\frames\\3.png does not exist ... '

# %%
if TRAIN_FROM_CHECKPOINT:
    try:
        yolo.load_weights(TRAIN_CHECKPOINTS_FOLDER + os.path.sep + TRAIN_MODEL_NAME)
    except ValueError:
        print("Shapes are incompatible, transfering from Darknet weights")
        TRAIN_FROM_CHECKPOINT = False
        
if TRAIN_TRANSFER and not TRAIN_FROM_CHECKPOINT:
    for i, l in enumerate(Darknet.layers):
        layer_weights = l.get_weights()
        if layer_weights != []:
            try:
                yolo.layers[i].set_weights(layer_weights)
            except:
                print("skipping", yolo.layers[i].name)

optimizer = tf.keras.optimizers.Adam()

# %%
def train_step(image_data, target):
    with tf.GradientTape() as tape:
        pred_result = yolo(image_data, training=True)
        giou_loss=conf_loss=prob_loss=0
        
        grid=3 if not TRAIN_YOLO_TINY else 2
        for i in range(grid):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i, CLASSES=TRAIN_CLASSES)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]
        total_loss = giou_loss + conf_loss + prob_loss
        gradients = tape.gradient(total_loss, yolo.trainable_variables)
        optimizer.apply_gradients(zip(gradients, yolo.trainable_variables))
        # update learning rate            
        global_steps.assign_add(1)
        if global_steps < warmup_steps:
            lr = global_steps / warmup_steps * TRAIN_LR_INIT
        else:
            lr = TRAIN_LR_END + 0.5 * (TRAIN_LR_INIT - TRAIN_LR_END) * ((1 + tf.cos((global_steps - warmup_steps) / (total_steps - warmup_steps) * (np.pi))))
                
        optimizer.lr.assign(lr.numpy())
        
        with writer.as_default():
            tf.summary.scalar("lr", optimizer.lr, step=global_steps)
            tf.summary.scalar("loss/total_loss", total_loss, step=global_steps)
            tf.summary.scalar("loss/giou_loss", giou_loss, step=global_steps)
            tf.summary.scalar("loss/conf_loss", conf_loss, step=global_steps)
            tf.summary.scalar("loss/prob_loss", prob_loss, step=global_steps)
        writer.flush()
    return global_steps.numpy(), optimizer.lr.numpy(), giou_loss.numpy(), conf_loss.numpy(), prob_loss.numpy(), total_loss.numpy()

# %%
validate_writer = tf.summary.create_file_writer(TRAIN_LOGDIR)
def validate_step(image_data, target):
    with tf.GradientTape() as tape:
        pred_result = yolo(image_data, training=False)
        giou_loss = conf_loss = prob_loss = 0
        grid=3 if not TRAIN_YOLO_TINY else 2
        for i in range(grid):
            conv, pred = pred_result[i*2], pred_result[i*2+1]
            loss_items = compute_loss(pred, conv, *target[i], i, CLASSES=TRAIN_CLASSES)
            giou_loss += loss_items[0]
            conf_loss += loss_items[1]
            prob_loss += loss_items[2]
        total_loss = giou_loss + conf_loss + prob_loss
    return giou_loss.numpy(), conf_loss.numpy(), prob_loss.numpy(), total_loss.numpy()

# %%
mAP_model = Create_Yolo(input_size=YOLO_INPUT_SIZE, CLASSES=TRAIN_CLASSES)
best_val_loss = 100000

# %%
for epoch in range(TRAIN_EPOCHS):
    for image_data, target in trainset:
        results = train_step(image_data, target)
        cur_step = results[0]%steps_per_epoch
        print("epoch:{:2.0f} step:{:5.0f}/{}, lr:{:.6f}, giou_loss:{:7.2f}, conf_loss:{:7.2f}, prob_loss:{:7.2f}, total_loss:{:7.2f}".format(epoch, cur_step, steps_per_epoch, results[1], results[2], results[3], results[4], results[5]))
    if len(testset) == 0:
        print("configure TEST options to validate model")
        yolo.save_weights(os.path_join(TRAIN_CHECKPOINT_FOLDER, TRAIN_MODEL_NAME))
        continue
    count, giou_val, conf_val, prob_val, total_val = 0.,0,0,0,0
    for image_data, target in testset:
        results = validate_step(image_data, target)
        count += 1
        giou_val += results[0]
        conf_val += results[1]
        prob_val += results[2]
        total_val+= results[3]
        print("total_val", total_val)
        
    with validate_writer.as_default():
        tf.summary.scalar("validate_loss/total_val", total_val/count, step=epoch)
        tf.summary.scalar("validate_loss/giou_val", giou_val/count, step=epoch)
        tf.summary.scalar("validate_loss/conf_val", conf_val/count, step=epoch)
        tf.summary.scalar("validate_loss/prob_val", prob_val/count, step=epoch)
    validate_writer.flush()
    print("\n\ngiou_val_loss:{:7.2f}, conf_val_loss:{:7.2f}, prob_val_loss:{:7.2f}, total_val_loss:{:7.2f}\n\n"
          .format(giou_val/count, conf_val/count, prob_val/count, total_val/count))
        
    if TRAIN_SAVE_CHECKPOINT and not TRAIN_SAVE_BEST_ONLY:
        save_directory = os.path.join(TRAIN_CHECKPOINTS_FOLDER, TRAIN_MODEL_NAME+"_val_loss_{:7.2f}".format(total_val/count))
        yolo.save_weights(save_directory)
    if TRAIN_SAVE_BEST_ONLY and best_val_loss>total_val/count:
        save_directory = os.path.join(TRAIN_CHECKPOINTS_FOLDER, TRAIN_MODEL_NAME)
        yolo.save_weights(save_directory)
        best_val_loss = total_val/count
    if not TRAIN_SAVE_BEST_ONLY and not TRAIN_SAVE_CHECKPOINT:
        save_directory = os.path.join(TRAIN_CHECKPOINTS_FOLDER, TRAIN_MODEL_NAME)
        yolo.save_weights(save_directory)
# Out:
# epoch: 0 step:    0/2, lr:0.000020, giou_loss:  51.49, conf_loss:1790.72, prob_loss:  10.62, total_loss:1852.83
# epoch: 0 step:    1/2, lr:0.000030, giou_loss:  49.97, conf_loss:1483.07, prob_loss:   9.76, total_loss:1542.80
# total_val 1740.6976318359375
# total_val 3493.574462890625
# total_val 5265.015625
#
#
# giou_val_loss:  58.65, conf_val_loss:1684.39, prob_val_loss:  11.97, total_val_loss:1755.01
#
#
# epoch: 1 step:    0/2, lr:0.000040, giou_loss:  56.97, conf_loss:1477.79, prob_loss:  11.13, total_loss:1545.89
# epoch: 1 step:    1/2, lr:0.000050, giou_loss:  47.95, conf_loss:1468.97, prob_loss:   9.10, total_loss:1526.02
# total_val 1753.56787109375
# total_val 3502.33447265625
# total_val 5203.497314453125
#
#
# giou_val_loss:  58.61, conf_val_loss:1663.96, prob_val_loss:  11.93, total_val_loss:1734.50
#
#
# epoch: 2 step:    0/2, lr:0.000060, giou_loss:  55.84, conf_loss:1456.79, prob_loss:  10.83, total_loss:1523.46
# epoch: 2 step:    1/2, lr:0.000070, giou_loss:  49.79, conf_loss:1437.78, prob_loss:   9.73, total_loss:1497.30
# total_val 1681.8140869140625
# total_val 3396.783935546875
# total_val 5100.35791015625
#
#
# giou_val_loss:  58.54, conf_val_loss:1629.72, prob_val_loss:  11.86, total_val_loss:1700.12
#
#
# epoch: 3 step:    0/2, lr:0.000080, giou_loss:  47.19, conf_loss:1422.22, prob_loss:   9.35, total_loss:1478.76
# epoch: 3 step:    1/2, lr:0.000090, giou_loss:  48.23, conf_loss:1403.08, prob_loss:   9.42, total_loss:1460.72
# total_val 1657.3753662109375
# total_val 3327.594482421875
# total_val 4943.92919921875
#
#
# giou_val_loss:  58.45, conf_val_loss:1577.74, prob_val_loss:  11.79, total_val_loss:1647.98
#
#
# epoch: 4 step:    0/2, lr:0.000100, giou_loss:  49.76, conf_loss:1382.86, prob_loss:   9.60, total_loss:1442.23
# epoch: 4 step:    1/2, lr:0.000100, giou_loss:  46.87, conf_loss:1353.19, prob_loss:   9.05, total_loss:1409.11
# total_val 1602.9625244140625
# total_val 3158.02978515625
# total_val 4754.6552734375
#
#
# giou_val_loss:  58.34, conf_val_loss:1514.80, prob_val_loss:  11.74, total_val_loss:1584.89
#
#
# epoch: 5 step:    0/2, lr:0.000100, giou_loss:  50.28, conf_loss:1319.01, prob_loss:   9.62, total_loss:1378.91
# epoch: 5 step:    1/2, lr:0.000100, giou_loss:  49.33, conf_loss:1300.89, prob_loss:   9.24, total_loss:1359.45
# total_val 1515.07568359375
# total_val 3038.0626220703125
# total_val 4557.2171630859375
#
#
# giou_val_loss:  58.25, conf_val_loss:1449.13, prob_val_loss:  11.69, total_val_loss:1519.07
#
#
# epoch: 6 step:    0/2, lr:0.000100, giou_loss:  49.23, conf_loss:1273.06, prob_loss:   8.96, total_loss:1331.25
# epoch: 6 step:    1/2, lr:0.000100, giou_loss:  45.39, conf_loss:1241.70, prob_loss:   8.29, total_loss:1295.38
# total_val 1449.978271484375
# total_val 2955.6719970703125
# total_val 4371.158935546875
#
#
# giou_val_loss:  58.19, conf_val_loss:1387.21, prob_val_loss:  11.65, total_val_loss:1457.05
#
#
# epoch: 7 step:    0/2, lr:0.000099, giou_loss:  47.55, conf_loss:1216.16, prob_loss:   8.86, total_loss:1272.57
# epoch: 7 step:    1/2, lr:0.000099, giou_loss:  48.67, conf_loss:1188.34, prob_loss:   9.11, total_loss:1246.12
# total_val 1384.5322265625
# total_val 2770.5771484375
# total_val 4193.157958984375
#
#
# giou_val_loss:  58.11, conf_val_loss:1328.00, prob_val_loss:  11.61, total_val_loss:1397.72
#
#
# epoch: 8 step:    0/2, lr:0.000099, giou_loss:  52.58, conf_loss:1167.90, prob_loss:   9.56, total_loss:1230.04
# epoch: 8 step:    1/2, lr:0.000099, giou_loss:  44.50, conf_loss:1141.40, prob_loss:   8.21, total_loss:1194.12
# total_val 1297.7791748046875
# total_val 2677.0892333984375
# total_val 4019.466064453125
#
#
# giou_val_loss:  58.02, conf_val_loss:1270.22, prob_val_loss:  11.59, total_val_loss:1339.82
#
#
# epoch: 9 step:    0/2, lr:0.000099, giou_loss:  55.46, conf_loss:1120.34, prob_loss:  10.21, total_loss:1186.02
# epoch: 9 step:    1/2, lr:0.000098, giou_loss:  49.76, conf_loss:1101.14, prob_loss:   8.91, total_loss:1159.80
# total_val 1308.8173828125
# total_val 2590.0277099609375
# total_val 3856.0743408203125
#
#
# giou_val_loss:  57.95, conf_val_loss:1215.84, prob_val_loss:  11.57, total_val_loss:1285.36
#
#
# epoch:10 step:    0/2, lr:0.000098, giou_loss:  51.39, conf_loss:1074.28, prob_loss:   9.03, total_loss:1134.70
# epoch:10 step:    1/2, lr:0.000098, giou_loss:  44.18, conf_loss:1047.41, prob_loss:   7.96, total_loss:1099.56
# total_val 1204.5303955078125
# total_val 2445.201171875
# total_val 3698.6539306640625
#
#
# giou_val_loss:  57.85, conf_val_loss:1163.54, prob_val_loss:  11.50, total_val_loss:1232.88
#
#
# epoch:11 step:    0/2, lr:0.000097, giou_loss:  47.15, conf_loss:1026.46, prob_loss:   8.29, total_loss:1081.90
# epoch:11 step:    1/2, lr:0.000097, giou_loss:  51.70, conf_loss:1033.89, prob_loss:   7.55, total_loss:1093.14
# total_val 1183.526611328125
# total_val 2381.219482421875
# total_val 3545.8681640625
#
#
# giou_val_loss:  57.72, conf_val_loss:1112.86, prob_val_loss:  11.38, total_val_loss:1181.96
#
#
# epoch:12 step:    0/2, lr:0.000096, giou_loss:  50.54, conf_loss: 995.70, prob_loss:   8.72, total_loss:1054.96
# epoch:12 step:    1/2, lr:0.000096, giou_loss:  47.18, conf_loss: 971.02, prob_loss:   8.16, total_loss:1026.36
# total_val 1116.296630859375
# total_val 2280.9041748046875
# total_val 3401.4033203125
#
#
# giou_val_loss:  57.54, conf_val_loss:1065.04, prob_val_loss:  11.22, total_val_loss:1133.80
#
#
# epoch:13 step:    0/2, lr:0.000095, giou_loss:  46.90, conf_loss: 949.55, prob_loss:   7.86, total_loss:1004.31
# epoch:13 step:    1/2, lr:0.000095, giou_loss:  47.71, conf_loss: 924.83, prob_loss:   8.12, total_loss: 980.66
# total_val 1074.212890625
# total_val 2179.1063232421875
# total_val 3257.491455078125
#
#
# giou_val_loss:  57.31, conf_val_loss:1017.51, prob_val_loss:  11.01, total_val_loss:1085.83
#
#
# epoch:14 step:    0/2, lr:0.000094, giou_loss:  48.44, conf_loss: 909.26, prob_loss:   8.00, total_loss: 965.70
# epoch:14 step:    1/2, lr:0.000094, giou_loss:  47.25, conf_loss: 888.42, prob_loss:   7.88, total_loss: 943.55
# total_val 1040.4918212890625
# total_val 2086.333740234375
# total_val 3123.3680419921875
#
#
# giou_val_loss:  57.02, conf_val_loss: 973.33, prob_val_loss:  10.77, total_val_loss:1041.12
#
#
# epoch:15 step:    0/2, lr:0.000093, giou_loss:  48.45, conf_loss: 878.66, prob_loss:   8.40, total_loss: 935.51
# epoch:15 step:    1/2, lr:0.000093, giou_loss:  45.05, conf_loss: 851.36, prob_loss:   7.36, total_loss: 903.78
# total_val 1019.077880859375
# total_val 1998.998779296875
# total_val 2999.166259765625
#
#
# giou_val_loss:  56.67, conf_val_loss: 932.57, prob_val_loss:  10.48, total_val_loss: 999.72
#
#
# epoch:16 step:    0/2, lr:0.000092, giou_loss:  53.15, conf_loss: 843.60, prob_loss:   8.61, total_loss: 905.36
# epoch:16 step:    1/2, lr:0.000091, giou_loss:  47.70, conf_loss: 832.04, prob_loss:   7.90, total_loss: 887.65
# total_val 991.3807983398438
# total_val 1924.3743286132812
# total_val 2881.818359375
#
#
# giou_val_loss:  56.30, conf_val_loss: 894.13, prob_val_loss:  10.18, total_val_loss: 960.61
#
#
# epoch:17 step:    0/2, lr:0.000091, giou_loss:  47.57, conf_loss: 823.17, prob_loss:   7.66, total_loss: 878.40
# epoch:17 step:    1/2, lr:0.000090, giou_loss:  48.34, conf_loss: 787.07, prob_loss:   7.80, total_loss: 843.21
# total_val 915.9669189453125
# total_val 1813.36279296875
# total_val 2773.5360107421875
#
#
# giou_val_loss:  55.92, conf_val_loss: 858.70, prob_val_loss:   9.89, total_val_loss: 924.51
#
#
# epoch:18 step:    0/2, lr:0.000089, giou_loss:  44.28, conf_loss: 781.41, prob_loss:   7.13, total_loss: 832.81
# epoch:18 step:    1/2, lr:0.000088, giou_loss:  45.70, conf_loss: 761.92, prob_loss:   7.30, total_loss: 814.91
# total_val 905.5438232421875
# total_val 1769.0465698242188
# total_val 2671.278564453125
#
#
# giou_val_loss:  55.54, conf_val_loss: 825.27, prob_val_loss:   9.62, total_val_loss: 890.43
#
#
# epoch:19 step:    0/2, lr:0.000088, giou_loss:  48.48, conf_loss: 748.24, prob_loss:   7.83, total_loss: 804.55
# epoch:19 step:    1/2, lr:0.000087, giou_loss:  47.99, conf_loss: 743.75, prob_loss:   7.55, total_loss: 799.29
# total_val 844.7451171875
# total_val 1722.213623046875
# total_val 2579.2813110351562
#
#
# giou_val_loss:  55.14, conf_val_loss: 795.27, prob_val_loss:   9.35, total_val_loss: 859.76
#
#
# epoch:20 step:    0/2, lr:0.000086, giou_loss:  46.08, conf_loss: 714.03, prob_loss:   7.22, total_loss: 767.33
# epoch:20 step:    1/2, lr:0.000085, giou_loss:  44.89, conf_loss: 698.15, prob_loss:   6.71, total_loss: 749.75
# total_val 870.9093627929688
# total_val 1685.7755737304688
# total_val 2494.6201171875
#
#
# giou_val_loss:  54.75, conf_val_loss: 767.69, prob_val_loss:   9.10, total_val_loss: 831.54
#
#
# epoch:21 step:    0/2, lr:0.000084, giou_loss:  44.89, conf_loss: 685.83, prob_loss:   6.92, total_loss: 737.63
# epoch:21 step:    1/2, lr:0.000083, giou_loss:  45.13, conf_loss: 672.84, prob_loss:   6.87, total_loss: 724.83
# total_val 826.6541748046875
# total_val 1612.9417114257812
# total_val 2415.8468017578125
#
#
# giou_val_loss:  54.37, conf_val_loss: 742.04, prob_val_loss:   8.88, total_val_loss: 805.28
#
#
# epoch:22 step:    0/2, lr:0.000082, giou_loss:  41.02, conf_loss: 666.46, prob_loss:   5.30, total_loss: 712.78
# epoch:22 step:    1/2, lr:0.000081, giou_loss:  42.41, conf_loss: 666.20, prob_loss:   6.52, total_loss: 715.13
# total_val 794.3175048828125
# total_val 1555.833251953125
# total_val 2341.1673583984375
#
#
# giou_val_loss:  53.98, conf_val_loss: 717.75, prob_val_loss:   8.66, total_val_loss: 780.39
#
#
# epoch:23 step:    0/2, lr:0.000081, giou_loss:  40.54, conf_loss: 639.00, prob_loss:   6.05, total_loss: 685.60
# epoch:23 step:    1/2, lr:0.000080, giou_loss:  48.13, conf_loss: 620.87, prob_loss:   7.34, total_loss: 676.34
# total_val 762.04345703125
# total_val 1513.1443481445312
# total_val 2268.76513671875
#
#
# giou_val_loss:  53.60, conf_val_loss: 694.19, prob_val_loss:   8.46, total_val_loss: 756.26
#
#
# epoch:24 step:    0/2, lr:0.000079, giou_loss:  44.26, conf_loss: 632.67, prob_loss:   6.88, total_loss: 683.81
# epoch:24 step:    1/2, lr:0.000078, giou_loss:  54.62, conf_loss: 621.38, prob_loss:   8.35, total_loss: 684.36
# total_val 740.7880859375
# total_val 1485.5466918945312
# total_val 2203.4132690429688
#
#
# giou_val_loss:  53.29, conf_val_loss: 672.88, prob_val_loss:   8.31, total_val_loss: 734.47
#
#
# epoch:25 step:    0/2, lr:0.000077, giou_loss:  41.41, conf_loss: 588.54, prob_loss:   5.80, total_loss: 635.75
# epoch:25 step:    1/2, lr:0.000076, giou_loss:  41.04, conf_loss: 574.61, prob_loss:   6.03, total_loss: 621.69
# total_val 722.1598510742188
# total_val 1426.77734375
# total_val 2141.149169921875
#
#
# giou_val_loss:  53.00, conf_val_loss: 652.53, prob_val_loss:   8.19, total_val_loss: 713.72
#
#
# epoch:26 step:    0/2, lr:0.000075, giou_loss:  45.59, conf_loss: 565.10, prob_loss:   6.57, total_loss: 617.26
# epoch:26 step:    1/2, lr:0.000074, giou_loss:  42.99, conf_loss: 553.69, prob_loss:   6.20, total_loss: 602.88
# total_val 709.725341796875
# total_val 1382.9453125
# total_val 2081.611083984375
#
#
# giou_val_loss:  52.71, conf_val_loss: 633.08, prob_val_loss:   8.08, total_val_loss: 693.87
#
#
# epoch:27 step:    0/2, lr:0.000072, giou_loss:  41.44, conf_loss: 550.53, prob_loss:   5.47, total_loss: 597.43
# epoch:27 step:    1/2, lr:0.000071, giou_loss:  41.90, conf_loss: 538.71, prob_loss:   6.17, total_loss: 586.78
# total_val 660.4742431640625
# total_val 1358.913818359375
# total_val 2024.181884765625
#
#
# giou_val_loss:  52.38, conf_val_loss: 614.40, prob_val_loss:   7.95, total_val_loss: 674.73
#
#
# epoch:28 step:    0/2, lr:0.000070, giou_loss:  40.19, conf_loss: 540.25, prob_loss:   5.84, total_loss: 586.28
# epoch:28 step:    1/2, lr:0.000069, giou_loss:  44.29, conf_loss: 515.86, prob_loss:   6.32, total_loss: 566.48
# total_val 657.7380981445312
# total_val 1313.0643920898438
# total_val 1972.125732421875
#
#
# giou_val_loss:  52.09, conf_val_loss: 597.44, prob_val_loss:   7.84, total_val_loss: 657.38
#
#
# epoch:29 step:    0/2, lr:0.000068, giou_loss:  41.42, conf_loss: 518.91, prob_loss:   5.98, total_loss: 566.31
# epoch:29 step:    1/2, lr:0.000067, giou_loss:  46.48, conf_loss: 500.82, prob_loss:   6.30, total_loss: 553.61
# total_val 651.8005981445312
# total_val 1280.13720703125
# total_val 1925.1896362304688
#
#
# giou_val_loss:  51.89, conf_val_loss: 582.07, prob_val_loss:   7.77, total_val_loss: 641.73
#
#
# epoch:30 step:    0/2, lr:0.000066, giou_loss:  46.02, conf_loss: 500.65, prob_loss:   6.23, total_loss: 552.90
# epoch:30 step:    1/2, lr:0.000065, giou_loss:  42.41, conf_loss: 485.02, prob_loss:   5.86, total_loss: 533.28
# total_val 622.6197509765625
# total_val 1267.1849365234375
# total_val 1877.8492431640625
#
#
# giou_val_loss:  51.70, conf_val_loss: 566.53, prob_val_loss:   7.72, total_val_loss: 625.95
#
#
# epoch:31 step:    0/2, lr:0.000064, giou_loss:  48.23, conf_loss: 479.84, prob_loss:   6.51, total_loss: 534.58
# epoch:31 step:    1/2, lr:0.000062, giou_loss:  45.13, conf_loss: 488.92, prob_loss:   6.68, total_loss: 540.74
# total_val 597.4468383789062
# total_val 1210.56591796875
# total_val 1832.9760131835938
#
#
# giou_val_loss:  51.53, conf_val_loss: 551.78, prob_val_loss:   7.68, total_val_loss: 610.99
#
#
# epoch:32 step:    0/2, lr:0.000061, giou_loss:  43.99, conf_loss: 469.88, prob_loss:   6.22, total_loss: 520.09
# epoch:32 step:    1/2, lr:0.000060, giou_loss:  43.01, conf_loss: 462.36, prob_loss:   6.11, total_loss: 511.47
# total_val 577.3855590820312
# total_val 1174.0220336914062
# total_val 1793.2019653320312
#
#
# giou_val_loss:  51.37, conf_val_loss: 538.72, prob_val_loss:   7.64, total_val_loss: 597.73
#
#
# epoch:33 step:    0/2, lr:0.000059, giou_loss:  41.40, conf_loss: 448.86, prob_loss:   5.68, total_loss: 495.95
# epoch:33 step:    1/2, lr:0.000058, giou_loss:  47.90, conf_loss: 448.18, prob_loss:   6.88, total_loss: 502.96
# total_val 573.985595703125
# total_val 1144.2450561523438
# total_val 1755.4551391601562
#
#
# giou_val_loss:  51.20, conf_val_loss: 526.36, prob_val_loss:   7.59, total_val_loss: 585.15
#
#
# epoch:34 step:    0/2, lr:0.000056, giou_loss:  46.30, conf_loss: 449.26, prob_loss:   6.40, total_loss: 501.96
# epoch:34 step:    1/2, lr:0.000055, giou_loss:  39.65, conf_loss: 437.07, prob_loss:   5.45, total_loss: 482.17
# total_val 572.7327880859375
# total_val 1159.10400390625
# total_val 1727.5795288085938
#
#
# giou_val_loss:  51.05, conf_val_loss: 517.27, prob_val_loss:   7.54, total_val_loss: 575.86
#
#
# epoch:35 step:    0/2, lr:0.000054, giou_loss:  44.13, conf_loss: 453.82, prob_loss:   6.27, total_loss: 504.23
# epoch:35 step:    1/2, lr:0.000053, giou_loss:  44.22, conf_loss: 424.97, prob_loss:   5.93, total_loss: 475.11
# total_val 558.83154296875
# total_val 1147.1265869140625
# total_val 1708.9222412109375
#
#
# giou_val_loss:  50.92, conf_val_loss: 511.23, prob_val_loss:   7.49, total_val_loss: 569.64
#
#
# epoch:36 step:    0/2, lr:0.000052, giou_loss:  40.42, conf_loss: 416.17, prob_loss:   5.17, total_loss: 461.76
# epoch:36 step:    1/2, lr:0.000050, giou_loss:  39.30, conf_loss: 419.31, prob_loss:   5.42, total_loss: 464.03
# total_val 568.9353637695312
# total_val 1141.60546875
# total_val 1691.9598999023438
#
#
# giou_val_loss:  50.73, conf_val_loss: 505.85, prob_val_loss:   7.41, total_val_loss: 563.99
#
#
# epoch:37 step:    0/2, lr:0.000049, giou_loss:  42.22, conf_loss: 414.39, prob_loss:   5.62, total_loss: 462.22
# epoch:37 step:    1/2, lr:0.000048, giou_loss:  40.82, conf_loss: 402.62, prob_loss:   5.15, total_loss: 448.59
# total_val 569.8427124023438
# total_val 1119.548583984375
# total_val 1675.9534301757812
#
#
# giou_val_loss:  50.49, conf_val_loss: 500.85, prob_val_loss:   7.30, total_val_loss: 558.65
#
#
# epoch:38 step:    0/2, lr:0.000047, giou_loss:  40.33, conf_loss: 401.50, prob_loss:   5.30, total_loss: 447.13
# epoch:38 step:    1/2, lr:0.000046, giou_loss:  36.88, conf_loss: 399.08, prob_loss:   4.75, total_loss: 440.71
# total_val 567.930908203125
# total_val 1121.7625122070312
# total_val 1660.5794677734375
#
#
# giou_val_loss:  50.22, conf_val_loss: 496.13, prob_val_loss:   7.18, total_val_loss: 553.53
#
#
# epoch:39 step:    0/2, lr:0.000045, giou_loss:  42.84, conf_loss: 391.72, prob_loss:   5.42, total_loss: 439.98
# epoch:39 step:    1/2, lr:0.000043, giou_loss:  45.35, conf_loss: 399.53, prob_loss:   5.58, total_loss: 450.46
# total_val 552.4304809570312
# total_val 1108.9766845703125
# total_val 1643.5596923828125
#
#
# giou_val_loss:  49.96, conf_val_loss: 490.83, prob_val_loss:   7.06, total_val_loss: 547.85
#
#
# epoch:40 step:    0/2, lr:0.000042, giou_loss:  41.75, conf_loss: 385.36, prob_loss:   5.22, total_loss: 432.32
# epoch:40 step:    1/2, lr:0.000041, giou_loss:  40.09, conf_loss: 378.84, prob_loss:   5.07, total_loss: 424.00
# total_val 547.5914916992188
# total_val 1099.3643798828125
# total_val 1624.8033447265625
#
#
# giou_val_loss:  49.74, conf_val_loss: 484.90, prob_val_loss:   6.95, total_val_loss: 541.60
# epoch:41 step:    0/2, lr:0.000040, giou_loss:  41.98, conf_loss: 385.16, prob_loss:   5.18, total_loss: 432.32
# epoch:41 step:    1/2, lr:0.000039, giou_loss:  36.59, conf_loss: 369.77, prob_loss:   4.29, total_loss: 410.64
# total_val 525.1842651367188
# total_val 1066.2894287109375
# total_val 1606.546630859375
#
#
# giou_val_loss:  49.57, conf_val_loss: 479.08, prob_val_loss:   6.87, total_val_loss: 535.52
#
#
# epoch:42 step:    0/2, lr:0.000037, giou_loss:  41.06, conf_loss: 368.83, prob_loss:   4.75, total_loss: 414.64
# epoch:42 step:    1/2, lr:0.000036, giou_loss:  40.44, conf_loss: 364.37, prob_loss:   4.78, total_loss: 409.59
# total_val 532.4258422851562
# total_val 1056.5205688476562
# total_val 1586.8721923828125
#
#
# giou_val_loss:  49.42, conf_val_loss: 472.73, prob_val_loss:   6.80, total_val_loss: 528.96
#
#
# epoch:43 step:    0/2, lr:0.000035, giou_loss:  39.29, conf_loss: 368.76, prob_loss:   4.90, total_loss: 412.95
# epoch:43 step:    1/2, lr:0.000034, giou_loss:  39.18, conf_loss: 358.20, prob_loss:   4.60, total_loss: 401.98
# total_val 535.4805908203125
# total_val 1054.4005126953125
# total_val 1567.8089599609375
#
#
# giou_val_loss:  49.33, conf_val_loss: 466.53, prob_val_loss:   6.75, total_val_loss: 522.60
#
#
# epoch:44 step:    0/2, lr:0.000033, giou_loss:  42.40, conf_loss: 361.86, prob_loss:   5.46, total_loss: 409.72
# epoch:44 step:    1/2, lr:0.000032, giou_loss:  35.89, conf_loss: 359.31, prob_loss:   4.55, total_loss: 399.75
# total_val 517.29443359375
# total_val 1021.1195678710938
# total_val 1549.2001342773438
#
#
# giou_val_loss:  49.25, conf_val_loss: 460.45, prob_val_loss:   6.70, total_val_loss: 516.40
#
#
# epoch:45 step:    0/2, lr:0.000031, giou_loss:  39.79, conf_loss: 356.23, prob_loss:   4.92, total_loss: 400.94
# epoch:45 step:    1/2, lr:0.000030, giou_loss:  44.74, conf_loss: 355.28, prob_loss:   5.47, total_loss: 405.49
# total_val 511.1488037109375
# total_val 1035.1443481445312
# total_val 1534.5674438476562
#
#
# giou_val_loss:  49.21, conf_val_loss: 455.64, prob_val_loss:   6.68, total_val_loss: 511.52
#
#
# epoch:46 step:    0/2, lr:0.000029, giou_loss:  42.01, conf_loss: 349.71, prob_loss:   5.31, total_loss: 397.03
# epoch:46 step:    1/2, lr:0.000027, giou_loss:  36.50, conf_loss: 344.38, prob_loss:   4.33, total_loss: 385.20
# total_val 507.6578063964844
# total_val 1009.5188598632812
# total_val 1521.8182983398438
#
#
# giou_val_loss:  49.18, conf_val_loss: 451.43, prob_val_loss:   6.66, total_val_loss: 507.27
#
#
# epoch:47 step:    0/2, lr:0.000026, giou_loss:  42.46, conf_loss: 354.13, prob_loss:   5.32, total_loss: 401.90
# epoch:47 step:    1/2, lr:0.000025, giou_loss:  38.83, conf_loss: 338.59, prob_loss:   4.52, total_loss: 381.95
# total_val 485.575927734375
# total_val 1014.7052001953125
# total_val 1510.1751098632812
#
#
# giou_val_loss:  49.20, conf_val_loss: 447.54, prob_val_loss:   6.65, total_val_loss: 503.39
#
#
# epoch:48 step:    0/2, lr:0.000024, giou_loss:  39.71, conf_loss: 344.07, prob_loss:   4.73, total_loss: 388.51
# epoch:48 step:    1/2, lr:0.000023, giou_loss:  38.20, conf_loss: 341.98, prob_loss:   4.65, total_loss: 384.83
# total_val 490.400146484375
# total_val 1000.1145935058594
# total_val 1498.2571716308594
#
#
# giou_val_loss:  49.19, conf_val_loss: 443.59, prob_val_loss:   6.64, total_val_loss: 499.42
#
#
# epoch:49 step:    0/2, lr:0.000022, giou_loss:  39.00, conf_loss: 338.81, prob_loss:   4.60, total_loss: 382.40
# epoch:49 step:    1/2, lr:0.000021, giou_loss:  38.33, conf_loss: 344.74, prob_loss:   4.98, total_loss: 388.05
# total_val 481.6524963378906
# total_val 1001.4801940917969
# total_val 1487.0760498046875
#
#
# giou_val_loss:  49.18, conf_val_loss: 439.88, prob_val_loss:   6.63, total_val_loss: 495.69
#
#
# epoch:50 step:    0/2, lr:0.000020, giou_loss:  41.45, conf_loss: 344.20, prob_loss:   5.70, total_loss: 391.35
# epoch:50 step:    1/2, lr:0.000020, giou_loss:  44.35, conf_loss: 335.77, prob_loss:   5.38, total_loss: 385.50
# total_val 479.90777587890625
# total_val 971.9022827148438
# total_val 1478.3373107910156
#
#
# giou_val_loss:  49.17, conf_val_loss: 436.99, prob_val_loss:   6.62, total_val_loss: 492.78
#
#
# epoch:51 step:    0/2, lr:0.000019, giou_loss:  40.20, conf_loss: 328.13, prob_loss:   4.63, total_loss: 372.97
# epoch:51 step:    1/2, lr:0.000018, giou_loss:  38.51, conf_loss: 332.32, prob_loss:   4.73, total_loss: 375.56
# total_val 494.1220397949219
# total_val 955.4651794433594
# total_val 1470.9592590332031
#
#
# giou_val_loss:  49.15, conf_val_loss: 434.57, prob_val_loss:   6.60, total_val_loss: 490.32
#
#
# epoch:52 step:    0/2, lr:0.000017, giou_loss:  41.29, conf_loss: 328.80, prob_loss:   5.24, total_loss: 375.33
# epoch:52 step:    1/2, lr:0.000016, giou_loss:  38.83, conf_loss: 327.63, prob_loss:   4.58, total_loss: 371.05
# total_val 483.5460205078125
# total_val 968.7249450683594
# total_val 1463.7841796875
#
#
# giou_val_loss:  49.11, conf_val_loss: 432.24, prob_val_loss:   6.58, total_val_loss: 487.93
#
#
# epoch:53 step:    0/2, lr:0.000015, giou_loss:  41.85, conf_loss: 325.36, prob_loss:   4.77, total_loss: 371.98
# epoch:53 step:    1/2, lr:0.000014, giou_loss:  37.23, conf_loss: 321.77, prob_loss:   4.11, total_loss: 363.10
# total_val 505.0816345214844
# total_val 992.3278198242188
# total_val 1456.8927001953125
#
#
# giou_val_loss:  49.06, conf_val_loss: 430.02, prob_val_loss:   6.55, total_val_loss: 485.63
#
#
# epoch:54 step:    0/2, lr:0.000013, giou_loss:  38.89, conf_loss: 326.48, prob_loss:   4.85, total_loss: 370.22
# epoch:54 step:    1/2, lr:0.000013, giou_loss:  34.26, conf_loss: 321.50, prob_loss:   3.74, total_loss: 359.50
# total_val 485.5018005371094
# total_val 948.5501098632812
# total_val 1449.7404174804688
#
#
# giou_val_loss:  48.99, conf_val_loss: 427.75, prob_val_loss:   6.51, total_val_loss: 483.25
#
#
# epoch:55 step:    0/2, lr:0.000012, giou_loss:  35.03, conf_loss: 328.13, prob_loss:   4.20, total_loss: 367.36
# epoch:55 step:    1/2, lr:0.000011, giou_loss:  39.03, conf_loss: 319.65, prob_loss:   4.46, total_loss: 363.14
# total_val 467.8763732910156
# total_val 947.9747924804688
# total_val 1443.3170471191406
#
#
# giou_val_loss:  48.92, conf_val_loss: 425.70, prob_val_loss:   6.48, total_val_loss: 481.11
#
#
# epoch:56 step:    0/2, lr:0.000010, giou_loss:  41.68, conf_loss: 320.68, prob_loss:   4.76, total_loss: 367.12
# epoch:56 step:    1/2, lr:0.000010, giou_loss:  36.09, conf_loss: 320.80, prob_loss:   4.40, total_loss: 361.29
# total_val 481.4919128417969
# total_val 946.2533264160156
# total_val 1436.6643981933594
#
#
# giou_val_loss:  48.86, conf_val_loss: 423.59, prob_val_loss:   6.44, total_val_loss: 478.89
#
#
# epoch:57 step:    0/2, lr:0.000009, giou_loss:  42.11, conf_loss: 317.80, prob_loss:   4.96, total_loss: 364.87
# epoch:57 step:    1/2, lr:0.000008, giou_loss:  40.67, conf_loss: 318.67, prob_loss:   4.77, total_loss: 364.10
# total_val 477.0683898925781
# total_val 958.483154296875
# total_val 1430.559326171875
#
#
# giou_val_loss:  48.80, conf_val_loss: 421.64, prob_val_loss:   6.41, total_val_loss: 476.85
#
#
# epoch:58 step:    0/2, lr:0.000008, giou_loss:  37.70, conf_loss: 316.76, prob_loss:   4.15, total_loss: 358.60
# epoch:58 step:    1/2, lr:0.000007, giou_loss:  45.57, conf_loss: 323.24, prob_loss:   5.33, total_loss: 374.13
# total_val 487.4054870605469
# total_val 964.0068359375
# total_val 1424.4965209960938
#
#
# giou_val_loss:  48.74, conf_val_loss: 419.71, prob_val_loss:   6.38, total_val_loss: 474.83
#
#
# epoch:59 step:    0/2, lr:0.000007, giou_loss:  36.51, conf_loss: 317.35, prob_loss:   4.43, total_loss: 358.30
# epoch:59 step:    1/2, lr:0.000006, giou_loss:  39.56, conf_loss: 322.77, prob_loss:   4.92, total_loss: 367.25
# total_val 478.8870849609375
# total_val 936.3245544433594
# total_val 1418.5959777832031
#
#
# giou_val_loss:  48.68, conf_val_loss: 417.82, prob_val_loss:   6.36, total_val_loss: 472.87
#
#
# epoch:60 step:    0/2, lr:0.000006, giou_loss:  36.82, conf_loss: 319.23, prob_loss:   4.64, total_loss: 360.68
# epoch:60 step:    1/2, lr:0.000005, giou_loss:  39.84, conf_loss: 312.74, prob_loss:   4.49, total_loss: 357.07
# total_val 459.0523376464844
# total_val 944.2670288085938
# total_val 1413.1784057617188
#
#
# giou_val_loss:  48.64, conf_val_loss: 416.08, prob_val_loss:   6.34, total_val_loss: 471.06
#
#
# epoch:61 step:    0/2, lr:0.000005, giou_loss:  42.93, conf_loss: 325.91, prob_loss:   5.12, total_loss: 373.97
# epoch:61 step:    1/2, lr:0.000004, giou_loss:  40.89, conf_loss: 320.93, prob_loss:   4.93, total_loss: 366.75
# total_val 444.5010070800781
# total_val 921.2498168945312
# total_val 1408.1270751953125
#
#
# giou_val_loss:  48.59, conf_val_loss: 414.47, prob_val_loss:   6.31, total_val_loss: 469.38
#
#
# epoch:62 step:    0/2, lr:0.000004, giou_loss:  37.49, conf_loss: 316.67, prob_loss:   4.83, total_loss: 358.99
# epoch:62 step:    1/2, lr:0.000003, giou_loss:  37.47, conf_loss: 312.46, prob_loss:   4.11, total_loss: 354.05
# total_val 459.283447265625
# total_val 919.3467407226562
# total_val 1403.19140625
#
#
# giou_val_loss:  48.56, conf_val_loss: 412.88, prob_val_loss:   6.29, total_val_loss: 467.73
#
#
# epoch:63 step:    0/2, lr:0.000003, giou_loss:  41.93, conf_loss: 314.63, prob_loss:   4.98, total_loss: 361.54
# epoch:63 step:    1/2, lr:0.000003, giou_loss:  42.68, conf_loss: 323.25, prob_loss:   5.47, total_loss: 371.40
# total_val 468.7588195800781
# total_val 950.5907897949219
# total_val 1398.6309509277344
#
#
# giou_val_loss:  48.52, conf_val_loss: 411.42, prob_val_loss:   6.27, total_val_loss: 466.21
#
#
# epoch:64 step:    0/2, lr:0.000002, giou_loss:  36.18, conf_loss: 312.97, prob_loss:   4.01, total_loss: 353.17
# epoch:64 step:    1/2, lr:0.000002, giou_loss:  41.99, conf_loss: 313.56, prob_loss:   4.67, total_loss: 360.21
# total_val 448.5359802246094
# total_val 922.2313232421875
# total_val 1394.6878662109375
#
#
# giou_val_loss:  48.49, conf_val_loss: 410.15, prob_val_loss:   6.26, total_val_loss: 464.90
#
#
# epoch:65 step:    0/2, lr:0.000002, giou_loss:  38.99, conf_loss: 313.67, prob_loss:   4.72, total_loss: 357.38
# epoch:65 step:    1/2, lr:0.000002, giou_loss:  42.39, conf_loss: 317.72, prob_loss:   5.10, total_loss: 365.21
# total_val 465.1029052734375
# total_val 930.3324279785156
# total_val 1390.2976379394531
#
#
# giou_val_loss:  48.45, conf_val_loss: 408.75, prob_val_loss:   6.24, total_val_loss: 463.43
#
#
# epoch:66 step:    0/2, lr:0.000002, giou_loss:  35.99, conf_loss: 310.98, prob_loss:   4.20, total_loss: 351.16
# epoch:66 step:    1/2, lr:0.000001, giou_loss:  37.79, conf_loss: 312.08, prob_loss:   4.25, total_loss: 354.12
# total_val 465.5638427734375
# total_val 930.1012878417969
# total_val 1386.6640014648438
#
#
# giou_val_loss:  48.42, conf_val_loss: 407.58, prob_val_loss:   6.22, total_val_loss: 462.22
#
#
# epoch:67 step:    0/2, lr:0.000001, giou_loss:  41.88, conf_loss: 314.79, prob_loss:   5.12, total_loss: 361.79
# epoch:67 step:    1/2, lr:0.000001, giou_loss:  39.47, conf_loss: 310.28, prob_loss:   4.49, total_loss: 354.24
# total_val 482.12030029296875
# total_val 931.6749877929688
# total_val 1382.8010559082031
#
#
# giou_val_loss:  48.39, conf_val_loss: 406.34, prob_val_loss:   6.21, total_val_loss: 460.93
#
#
# epoch:68 step:    0/2, lr:0.000001, giou_loss:  41.28, conf_loss: 320.29, prob_loss:   5.00, total_loss: 366.57
# epoch:68 step:    1/2, lr:0.000001, giou_loss:  37.50, conf_loss: 312.82, prob_loss:   4.35, total_loss: 354.67
# total_val 434.9814147949219
# total_val 918.4596252441406
# total_val 1378.4384460449219
#
#
# giou_val_loss:  48.35, conf_val_loss: 404.94, prob_val_loss:   6.19, total_val_loss: 459.48
#
#
# epoch:69 step:    0/2, lr:0.000001, giou_loss:  38.17, conf_loss: 311.18, prob_loss:   4.19, total_loss: 353.54
# epoch:69 step:    1/2, lr:0.000001, giou_loss:  42.56, conf_loss: 322.63, prob_loss:   5.25, total_loss: 370.44
# total_val 434.04083251953125
# total_val 911.2197570800781
# total_val 1373.7334289550781
#
#
# giou_val_loss:  48.32, conf_val_loss: 403.41, prob_val_loss:   6.18, total_val_loss: 457.91
